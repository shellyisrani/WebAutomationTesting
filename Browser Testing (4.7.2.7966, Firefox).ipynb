# %% [markdown]
# Install/run the below line if package not already installed

# %%
# pip install selenium

# %% [markdown]
# Import the below packages before continuing

# %%
from selenium import webdriver # connect to browser instance
from selenium.webdriver.common.keys import Keys # lets you emulate the stroke of keyboard keys
from selenium.webdriver.common.action_chains import ActionChains # lets you perform action elements
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
import time
from time import sleep

# %% [markdown]
# Set **driver_loc** - this sets the location of the driver, so you can use this variable multiple times when logging into DTS instead of inputting the location everytime
#
# Set **gecko_log** - this sets the location of the firefox/gecko log file; if this is not set, when running the .bat file a permission error will be thrown

# %%
driver_loc = (r'C:\BrowserTesting\drivers\geckodriver.exe')
gecko_log = (r'C:\BrowserTesting\geckodriver.log')

# %% [markdown]
# Check DTS login to make sure connection takes

# %%
# check DTS login
driver = webdriver.Firefox(executable_path = driver_loc, log_path = gecko_log)

def DTS_login():
    driver.get ('http://dtsadminuser:dtsadmin@localhost:8080/dtsserverws/')
       
DTS_login()

time.sleep(3)
driver.quit()

# %% [markdown]
# ## Tree Panel Tests

# %% [markdown]
# ### Tree Panel Loops
# #### Namespaces, first child concept, concept selection, and namespace drop downs (all of this for Id, Code, and Name as well)
#
# <u>The below code does the following:</u>
# - Loops through Tree Panel and selects all namespaces, one by one, so they appear on the right hand side (details panel)
# - Loops through the Tree Panel and drops down all namespaces, one by one (by one level only)
# - Loops through the Tree Panel again and selects all namespaces and their corresponding concepts that have been dropped by the previous function
#     - <u>Does the above three times by looping through Id, Code, and Name in the 'List by Concepts Panel' dropdown</u>
# - Loops through the Namespace drop down bar at the top and selects all namespaces
# - Ends the code with re-selecting 'All Namespaces' for a view of the entire Tree

# %%
# tree panel loops
driver = webdriver.Firefox(executable_path = driver_loc, log_path = gecko_log)

def DTS_login():
    driver.get ('http://dtsadminuser:dtsadmin@localhost:8080/dtsserverws/')
       
DTS_login()

driver.maximize_window()
time.sleep(0.5)

# loop to select all namespaces
select_nm = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-lbl']")
for x in range(0,len(select_nm)):
    if select_nm[x].is_displayed():
        select_nm[x].click()
        time.sleep(0.2)
time.sleep(2)        
        
# loop to drop down all namespaces (by one only)
expand_nm = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")
for x in range(0,len(expand_nm)):
    if expand_nm[x].is_displayed():
        expand_nm[x].click()
        time.sleep(0.2)
time.sleep(2)
        
# loop to select all concepts
select_cn = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-lbl']")
for x in range(0,len(select_cn)):
    if select_cn[x].is_displayed():
        select_cn[x].click()
        time.sleep(0.2)
time.sleep(2)

####################################################################
# loop through concepts dropdown
# ID
concepts_id = Select(driver.find_element_by_id("contentForm:sortby"));
concepts_id.select_by_visible_text('Id')
time.sleep(1)   

# loop to select all namespaces
select_nm = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-lbl']")
for x in range(0,len(select_nm)):
    if select_nm[x].is_displayed():
        select_nm[x].click()
        time.sleep(0.2)
time.sleep(2)        
        
# loop to drop down all namespaces (by one only)
expand_nm = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")
for x in range(0,len(expand_nm)):
    if expand_nm[x].is_displayed():
        expand_nm[x].click()
        time.sleep(0.2)
time.sleep(2)
        
# loop to select all concepts
select_cn = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-lbl']")
for x in range(0,len(select_cn)):
    if select_cn[x].is_displayed():
        select_cn[x].click()
        time.sleep(0.2)
time.sleep(2)

#######################################################################
# loop through concepts dropdown
# Code
concepts_code = Select(driver.find_element_by_id("contentForm:sortby"));
concepts_code.select_by_visible_text('Code')
time.sleep(1)

# loop to select all namespaces
select_nm = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-lbl']")
for x in range(0,len(select_nm)):
    if select_nm[x].is_displayed():
        select_nm[x].click()
        time.sleep(0.2)
time.sleep(2)        
        
# loop to drop down all namespaces (by one only)
expand_nm = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")
for x in range(0,len(expand_nm)):
    if expand_nm[x].is_displayed():
        expand_nm[x].click()
        time.sleep(0.2)
time.sleep(2)
        
# loop to select all concepts
select_cn = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-lbl']")
for x in range(0,len(select_cn)):
    if select_cn[x].is_displayed():
        select_cn[x].click()
        time.sleep(0.2)
time.sleep(2) 

#######################################################################    
# loop through concepts dropdown
# Name
concepts_name = Select(driver.find_element_by_id("contentForm:sortby"));
concepts_name.select_by_visible_text('Name')
time.sleep(1)

# loop to select all namespaces
select_nm = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-lbl']")
for x in range(0,len(select_nm)):
    if select_nm[x].is_displayed():
        select_nm[x].click()
        time.sleep(0.2)
time.sleep(2)        
        
# loop to drop down all namespaces (by one only)
expand_nm = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")
for x in range(0,len(expand_nm)):
    if expand_nm[x].is_displayed():
        expand_nm[x].click()
        time.sleep(0.2)
time.sleep(2)
        
# loop to select all concepts
select_cn = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-lbl']")
for x in range(0,len(select_cn)):
    if select_cn[x].is_displayed():
        select_cn[x].click()
        time.sleep(0.2)
time.sleep(2)  

#######################################################################       
# loop through namespace dropdown
select = Select(driver.find_element_by_id("contentForm:treeNamespace"))

options = select.options
for opt in select.options:
    opt.click()
time.sleep(1)
    
# end with 'All Namespaces'
namespace = Select(driver.find_element_by_id("contentForm:treeNamespace"));
namespace.select_by_visible_text('All Namespaces')    

time.sleep(3)
driver.quit()

# %% [markdown]
# ### Namespace and Concept Expansion
#
# <u>The below code does the following:</u>
#
# **Part 1 - States of the Union**
#
# - Expands States of the Union and the first child concept (States)
# - Expands first and second child concept within States (East, North)
# - Click on Connecticut and Alaska to make sure concepts show in details panel
# - Click back on namespace and collapse dropdown
#
# **Part 2 - Triad**
#
# - Expands Triad and the first / second child concept (ANALYTIC_TECHNIQUE, DIAGNOSIS)
# - Clicks ANALYTIC_TECHNIQUE and one child concept from DIAGNOSIS (SUBSTANCE_ABUSE)
# - Clicks back on namespace and collapses dropdown
#
#
# **Namespaces to run against**
# - Thesaurus: States of the Union
# - Ontylog: Triad
# - Ontylog Extension: **Still need Ontylog Extension**
#
#
# ##### <u>Note:</u>
# When selecting namespaces, the end brackets '[]' selects the number in which they appear in the tree
# - Starts from 0, i.e., first namespace in the tree will be [0], second will be [1], and so forth
# - When running the code, **be sure to adjust these numbers at the end of the code!**
#
#
# ### Property/Association/Qualifier type tabs with versioning loop
#
# <u>The below code does the following:</u>
# - Loop through three different tabs in selected namespaces (property, association, qualifier)
# - Dropdown the most recent version (working version), dropdown its root, click on specified root and end with clicking on namespace again

# %%
# namespace and concept expansion (States of the Union, Triad)
# attribute and working version dropdown
driver = webdriver.Firefox(executable_path = driver_loc, log_path = gecko_log)

def DTS_login():
    driver.get ('http://dtsadminuser:dtsadmin@localhost:8080/dtsserverws/')
       
DTS_login()

driver.maximize_window()
time.sleep(0.5)

#########################################
# STATES OF THE UNION
#########################################
# drop down States of the Union
def get_label():
    driver.find_element_by_link_text("States of the Union").click()

# selects States of the Union
get_label()
time.sleep(1)
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")[5].click()
time.sleep(1)
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")[5].click()
time.sleep(1)
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")[5].click() # 1st child
time.sleep(1)
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")[5].click() # 2nd child
time.sleep(1)
driver.find_element_by_link_text("Connecticut").click()
time.sleep(1)
driver.find_element_by_link_text("Alaska").click()
time.sleep(1)
get_label()
time.sleep(1)
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-exp rf-trn-hnd']")[0].click() # collapse all
time.sleep(1)

#########################################
# TRIAD
#########################################
# Triad
# new function so clicks land on Triad instead of States of the Union
def get_label1():
    driver.find_element_by_link_text("Triad").click()

get_label1()
time.sleep(1)
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")[7].click()
time.sleep(1)
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")[7].click() # 1st child
time.sleep(1)
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")[7].click() # 2nd child
time.sleep(1)
driver.find_element_by_link_text("ANALYTIC_TECHNIQUE").click()
time.sleep(1)
driver.find_element_by_link_text("SUBSTANCE_ABUSE").click()
time.sleep(1)
get_label1()
time.sleep(1)
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-exp rf-trn-hnd']")[0].click() # collapse all
time.sleep(1)


########################################################################
# Test out Attribute Tabs and Working version
#########################################
# STATES OF THE UNION 
#########################################
# States of the Union atrribute tabs
driver.find_element_by_link_text("States of the Union").click()
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:namespaceTypePanel:header']//td[@class='rf-cp-ico']").click() # drop down attributes
time.sleep(1)
driver.find_element_by_xpath("//td[@id='detailsForm:spaceAssnTypeTab:header:inactive']//span[@class='rf-tab-lbl']").click()
time.sleep(1)
driver.find_element_by_xpath("//td[@id='detailsForm:spaceQualTypeTab:header:inactive']//span[@class='rf-tab-lbl']").click()
time.sleep(1)
driver.find_element_by_xpath("//td[@id='detailsForm:spacePropTypeTab:header:inactive']//span[@class='rf-tab-lbl']").click()
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:namespaceTypePanel:header']//td[@class='rf-cp-ico']").click() # collapse attributes

# States of the Union working version
# drop down working version
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt306:0:j_idt307:header']//td[@class='rf-cp-ico']").click() # drop down attributes
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt306:0:j_idt320:header']//td[@class='rf-cp-ico']").click()
time.sleep(1)
driver.find_element_by_link_text("States").click()
time.sleep(1)
driver.find_element_by_link_text("States of the Union").click()
time.sleep(1)


#########################################
# TRIAD
#########################################
# Triad Tabs
driver.find_element_by_link_text("Triad").click()
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:namespaceTypePanel:header']//td[@class='rf-cp-ico']").click() # drop down attributes
time.sleep(1)
driver.find_element_by_xpath("//td[@id='detailsForm:spaceAssnTypeTab:header:inactive']//span[@class='rf-tab-lbl']").click()
time.sleep(1)
driver.find_element_by_xpath("//td[@id='detailsForm:spaceQualTypeTab:header:inactive']//span[@class='rf-tab-lbl']").click()
time.sleep(1)
driver.find_element_by_xpath("//td[@id='detailsForm:spacePropTypeTab:header:inactive']//span[@class='rf-tab-lbl']").click()
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:namespaceTypePanel:header']//td[@class='rf-cp-ico']").click() # collapse attributes

# Triad working version
# drop down working version
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt306:0:j_idt307:header']//td[@class='rf-cp-ico']").click() # drop down attributes
time.sleep(1)
driver.find_element_by_link_text("MEASURABLE_SUBSTANCE").click()
time.sleep(1)
driver.find_element_by_link_text("Triad").click()

time.sleep(3)
driver.quit()

# %% [markdown]
# ### Namespace Versioning loop
# Tests namespace versions and concepts on older namespace versions in details panel
#
#
# <u>The below code does the following: </u>
# - Runs through select namespaces and then runs through each corresponding version of selected namespace
# - Clicks on concepts/child concepts for older versions
#     - Will loop through versioning and select inferred/definied for older versions to make sure everything works
# - This will be run once for Thesaurus, Ontylog, and Ontylog Extension namespaces
#
# The namespaces that will be used are:
# - Thesaurus: States of the union
# - Ontylog: Triad
# - Ontylog Extension: **Still need Ontylog Extension**

# %%
# version and concept loop with namespace selection - States of the Union, Triad
driver = webdriver.Firefox(executable_path = driver_loc, log_path = gecko_log)

def DTS_login():
    driver.get ('http://dtsadminuser:dtsadmin@localhost:8080/dtsserverws/')
       
DTS_login()

driver.maximize_window()
time.sleep(0.5)

#########################################
# STATES OF THE UNION
#########################################
driver.find_element_by_xpath("//select[@id='contentForm:treeNamespace']/option[text()='States of the Union']").click()
time.sleep(3) 

# loop to drop down all namespaces (by one only)
expand_nm = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")
for x in range(0,len(expand_nm)):
    if expand_nm[x].is_displayed():
        expand_nm[x].click()
        time.sleep(0.5)
time.sleep(2)
        
# loop to select all concepts
select_cn = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-lbl']")
for x in range(0,len(select_cn)):
    if select_cn[x].is_displayed():
        select_cn[x].click()
time.sleep(2)

# loop through 'List Concepts By'
select = Select(driver.find_element_by_id("contentForm:sortby"))
options = select.options

for opt in select.options:
    opt.click()
    
time.sleep(2)

# loop through version dropdown
select = Select(driver.find_element_by_id("contentForm:treeRelease"))
options = select.options

for opt in select.options:
    opt.click()
    
time.sleep(2)

# loop to drop down all first child concepts
expand_nm = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")
for x in range(0,len(expand_nm)):
    if expand_nm[x].is_displayed():
        expand_nm[x].click()
time.sleep(2)

# loop to drop down all second concepts
expand_cn = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")
for x in range(0,len(expand_cn)):
    if expand_cn[x].is_displayed():
        expand_cn[x].click()
time.sleep(2)
        
# loop to select all concepts
select_cn = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-lbl']")
for x in range(0,len(select_cn)):
    if select_cn[x].is_displayed():
        select_cn[x].click()
time.sleep(2)

# loop to test out older versions in details panel
driver.find_element_by_link_text("Vermont").click()
time.sleep(1)

# loop through versioning of child concept Vermont
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from current to version
type_select.select_by_visible_text('Version')
time.sleep(2)

select = Select(driver.find_element_by_id("detailsForm:concept_version")) # loop
options = select.options
time.sleep(1)

for opt in select.options:
    opt.click()
    
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# go back to working version
version = Select(driver.find_element_by_id("detailsForm:concept_version")); # go to most recent version
version.select_by_visible_text('Working')

# select current type
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from version to current
type_select.select_by_visible_text('Current')
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

driver.find_element_by_link_text("East").click()
time.sleep(1)

# end with most recent version
################ IF YOU DON'T END WITH MOST RECENT VERSION IT REFLECTS THE LAST SELECTED VERSION IN THE TREE
type_select = Select(driver.find_element_by_id("contentForm:treeRelease")); # change from current to version
type_select.select_by_visible_text('Working')
time.sleep(2)

# end with 'All Namespaces'
namespace = Select(driver.find_element_by_id("contentForm:treeNamespace"));
namespace.select_by_visible_text('All Namespaces')  
time.sleep(2)

#########################################
# TRIAD
#########################################
namespace = Select(driver.find_element_by_id("contentForm:treeNamespace"));
namespace.select_by_visible_text('Triad')
time.sleep(1)
  
# loop to drop down all first child concepts
expand_nm = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")
for x in range(0,len(expand_nm)):
    if expand_nm[x].is_displayed():
        expand_nm[x].click()
time.sleep(2)
        
# loop to select all concepts
select_cn = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-lbl']")
for x in range(0,len(select_cn)):
    if select_cn[x].is_displayed():
        select_cn[x].click()
time.sleep(2)

# loop through 'List Concepts By'
select = Select(driver.find_element_by_id("contentForm:sortby"))
options = select.options

for opt in select.options:
    opt.click()
    
time.sleep(2)

# loop through version dropdown
select = Select(driver.find_element_by_id("contentForm:treeRelease"))
options = select.options

for opt in select.options:
    opt.click()  
    
time.sleep(2)

# loop to drop down first child concept
expand_nm = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")
for x in range(0,len(expand_nm)):
    if expand_nm[x].is_displayed():
        expand_nm[x].click()
time.sleep(2)
        
# loop to select all concepts
select_cn = driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-lbl']")
for x in range(0,len(select_cn)):
    if select_cn[x].is_displayed():
        select_cn[x].click()
time.sleep(2)

# select child concept and test out in details panel
driver.find_element_by_link_text("CHEMICAL").click()
time.sleep(1)
driver.find_element_by_link_text("CHEMICAL_VIEWED_FUNCTIONALLY").click()
time.sleep(1)

# loop through versioning of child concept CHEMICAL_VIEWED_FUNCTIONALLY
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from current to version
type_select.select_by_visible_text('Version')
time.sleep(2)

select = Select(driver.find_element_by_id("detailsForm:concept_version")) # loop
options = select.options
time.sleep(1)

for opt in select.options:
    opt.click()
    
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# test inferred/defined versioning loop
type_select = Select(driver.find_element_by_id("detailsForm:j_idt213")); # change from current to version
type_select.select_by_visible_text('Defined')
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

select = Select(driver.find_element_by_id("detailsForm:concept_version")) # loop
options = select.options
time.sleep(1)

for opt in select.options:
    opt.click()
    
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

type_select = Select(driver.find_element_by_id("detailsForm:j_idt213")); # change from current to version
type_select.select_by_visible_text('Inferred')
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# go back to working version
version = Select(driver.find_element_by_id("detailsForm:concept_version")); # go to most recent version
version.select_by_visible_text('2010.02(Feb 1, 2010 12:00:00 AM)')

# select current type
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from version to current
type_select.select_by_visible_text('Current')
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# end with most recent version
################ IF YOU DON'T END WITH MOST RECENT VERSION IT REFLECTS THE LAST SELECTED VERSION IN THE TREE
type_select = Select(driver.find_element_by_id("contentForm:treeRelease")); # change from current to version
type_select.select_by_visible_text('2010.02(Feb 1, 2010 12:00:00 AM)')
time.sleep(2)


# end with 'All Namespaces'
namespace = Select(driver.find_element_by_id("contentForm:treeNamespace"));
namespace.select_by_visible_text('All Namespaces')

time.sleep(3)
driver.quit()

# %% [markdown]
# ### Namespace and Subset Tab in Tree Panel
#
# <u>The below code does the following:</u>
# - Clicks on Namespace Tab in the Tree Panel
# - Selects "All" Namespaces to get all namespaces
#     - Goes through States of the Union and Triad (Inferred & Defined) and clicks through versioning and concepts in the Details Panel
# - Selects "Extends" and selects Triad - looks at Triad Extensions (if applicable)
# - Clicks on Subset Tab in Tree Panel and finds all subsets
# - Ends in the Tree Panel
#
# **Still need Ontylog Extension**

# %%
# namespace and subset tab tests in tree panel
driver = webdriver.Firefox(executable_path = driver_loc, log_path = gecko_log)

def DTS_login():
    driver.get ('http://dtsadminuser:dtsadmin@localhost:8080/dtsserverws/')
       
DTS_login()

driver.maximize_window()
time.sleep(0.5)

##############################
# Move splitter
# get element  
element = driver.find_element_by_class_name("vsplitter") 
  
# create action chain object 
action = ActionChains(driver) 
  
# drag_and_drop_by_offset the item 
action.drag_and_drop_by_offset(element, 100, 220) 
  
# perform the operation 
action.perform()
##############################

# click namespace tab in tree panel
driver.find_element_by_id("contentForm:namespaceListTab:header:inactive").click()
time.sleep(1)

# select 'All' in case not already selected
type_select = Select(driver.find_element_by_id("contentForm:nsSelect")); # change from current to version
type_select.select_by_visible_text('All')
time.sleep(1)

# click search
driver.find_element_by_id("contentForm:j_idt144").click()
time.sleep(1)

#########################################
# STATES OF THE UNION
#########################################
# test details panel for States of the Union
driver.find_element_by_link_text("States of the Union").click()
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt306:0:j_idt307:header']//td[@class='rf-cp-ico']").click() # drop down attributes
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt306:0:j_idt320:header']//td[@class='rf-cp-ico']").click()
time.sleep(1)
driver.find_element_by_link_text("States").click()
time.sleep(1)

# loop through versioning
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from current to version
type_select.select_by_visible_text('Version')
time.sleep(2)

select = Select(driver.find_element_by_id("detailsForm:concept_version")) # loop
options = select.options
time.sleep(1)

for opt in select.options:
    opt.click()
    
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# go back to working version
version = Select(driver.find_element_by_id("detailsForm:concept_version")); # go to most recent version
version.select_by_visible_text('Working')

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# select current type
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from version to current
type_select.select_by_visible_text('Current')
time.sleep(2)

# click around
driver.find_element_by_link_text("Republicans").click()
time.sleep(1)
driver.find_element_by_link_text("Texas").click()
time.sleep(1)
driver.find_element_by_link_text("South").click()
time.sleep(1)
##############################

#########################################
# TRIAD
#########################################
# test details panel for Triad (INFERRED)
driver.find_element_by_link_text("Triad").click()
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt306:0:j_idt307:header']//td[@class='rf-cp-ico']").click() # drop down attributes
time.sleep(1)
driver.find_element_by_link_text("PROCEDURE").click()
time.sleep(1)

# loop through versioning
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from current to version
type_select.select_by_visible_text('Version')
time.sleep(2)

select = Select(driver.find_element_by_id("detailsForm:concept_version")) # loop
options = select.options
time.sleep(1)

for opt in select.options:
    opt.click()
    
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# go back to working version
version = Select(driver.find_element_by_id("detailsForm:concept_version")); # go to most recent version
version.select_by_visible_text('2010.02(Feb 1, 2010 12:00:00 AM)')

# select current type
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from version to current
type_select.select_by_visible_text('Current')
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# click around
driver.find_element_by_link_text("DIAGNOSTIC_PROCEDURE").click()
time.sleep(1)
driver.find_element_by_link_text("LABORATORY_DIAGNOSTIC_PROCEDURE").click()
time.sleep(2)
driver.find_element_by_link_text("Laboratory Diagnostic Procedure").click()
time.sleep(1)
##############################

##############################
# test details panel for Triad (DEFINED)
driver.find_element_by_link_text("Triad").click()
time.sleep(1)
driver.find_element_by_link_text("PROCEDURE").click()
time.sleep(1)

# make defined
type_select = Select(driver.find_element_by_id("detailsForm:j_idt213")); # change from current to version
type_select.select_by_visible_text('Defined')
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# loop through versioning
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from current to version
type_select.select_by_visible_text('Version')
time.sleep(2)

select = Select(driver.find_element_by_id("detailsForm:concept_version")) # loop
options = select.options
time.sleep(1)

for opt in select.options:
    opt.click()
    
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# go back to working version
version = Select(driver.find_element_by_id("detailsForm:concept_version")); # go to most recent version
version.select_by_visible_text('2010.02(Feb 1, 2010 12:00:00 AM)')

# select current type
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from version to current
type_select.select_by_visible_text('Current')
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# click around
driver.find_element_by_link_text("DIAGNOSTIC_PROCEDURE").click()
time.sleep(1)
driver.find_element_by_link_text("LABORATORY_DIAGNOSTIC_PROCEDURE").click()
time.sleep(2)
driver.find_element_by_link_text("Laboratory Diagnostic Procedure").click()
time.sleep(1)
##############################

# select 'Extends' 
type_select = Select(driver.find_element_by_id("contentForm:nsSelect")); # change from current to version
type_select.select_by_visible_text('Extends')
time.sleep(1)

type_select = Select(driver.find_element_by_id("contentForm:nsExtends")); # change from current to version
type_select.select_by_visible_text('Triad')
time.sleep(1)

driver.find_element_by_id("contentForm:j_idt144").click()
time.sleep(1)

##############################
# click subset tab in tree panel
driver.find_element_by_id("contentForm:subsetListTab:header:inactive").click()
time.sleep(1)

# select 'All' in case not already selected
type_select = Select(driver.find_element_by_id("contentForm:ssSelect")); # change from current to version
type_select.select_by_visible_text('All')
time.sleep(2)

# click search
driver.find_element_by_id("contentForm:j_idt176").click()
time.sleep(1)

#########################################
# SUBSET SELECTION
#########################################
# select Subset 1
driver.find_element_by_link_text("Subset1").click()
time.sleep(1)
# drop down attributes
driver.find_element_by_xpath("//div[@id='detailsForm:subsetTypePanel:header']//td[@class='rf-cp-ico']").click() # drop down attributes
time.sleep(1)
driver.find_element_by_xpath("//td[@id='detailsForm:subsetQualTypeTab:header:inactive']//span[@class='rf-tab-lbl']").click()
time.sleep(1)
driver.find_element_by_xpath("//td[@id='detailsForm:subsetPropTypeTab:header:inactive']//span[@class='rf-tab-lbl']").click()
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:subsetTypePanel:header']//td[@class='rf-cp-ico']").click() # close dropdown
time.sleep(1)
# drop down working version
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt589:0:j_idt590:header']//td[@class='rf-cp-ico']").click() # drop down attributes
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt589:0:j_idt604:header']//td[@class='rf-cp-ico']").click()
time.sleep(1)
# close dropdowns
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt589:0:j_idt604:header']//td[@class='rf-cp-ico']").click()
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt589:0:j_idt590:header']//td[@class='rf-cp-ico']").click()

# select Subset 2
driver.find_element_by_link_text("Subset2").click()
time.sleep(1)
# drop down attributes
driver.find_element_by_xpath("//div[@id='detailsForm:subsetTypePanel:header']//td[@class='rf-cp-ico']").click() # drop down attributes
time.sleep(1)
driver.find_element_by_xpath("//td[@id='detailsForm:subsetQualTypeTab:header:inactive']//span[@class='rf-tab-lbl']").click()
time.sleep(1)
driver.find_element_by_xpath("//td[@id='detailsForm:subsetPropTypeTab:header:inactive']//span[@class='rf-tab-lbl']").click()
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:subsetTypePanel:header']//td[@class='rf-cp-ico']").click() # close dropdown
time.sleep(1)
# drop down working version
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt589:0:j_idt590:header']//td[@class='rf-cp-ico']").click() # drop down attributes
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt589:0:j_idt604:header']//td[@class='rf-cp-ico']").click()
time.sleep(1)
# close dropdowns
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt589:0:j_idt604:header']//td[@class='rf-cp-ico']").click()
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt589:0:j_idt590:header']//td[@class='rf-cp-ico']").click()


# select Subset 3
driver.find_element_by_link_text("Subset3").click()
time.sleep(2)
# drop down attributes
driver.find_element_by_xpath("//div[@id='detailsForm:subsetTypePanel:header']//td[@class='rf-cp-ico']").click() # drop down attributes
time.sleep(2)
driver.find_element_by_xpath("//td[@id='detailsForm:subsetQualTypeTab:header:inactive']//span[@class='rf-tab-lbl']").click()
time.sleep(1)
driver.find_element_by_xpath("//td[@id='detailsForm:subsetPropTypeTab:header:inactive']//span[@class='rf-tab-lbl']").click()
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:subsetTypePanel:header']//td[@class='rf-cp-ico']").click() # close dropdown
time.sleep(1)
# drop down working version
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt589:0:j_idt590:header']//td[@class='rf-cp-ico']").click() # drop down attributes
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt589:0:j_idt604:header']//td[@class='rf-cp-ico']").click()
time.sleep(1)
# close dropdowns
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt589:0:j_idt604:header']//td[@class='rf-cp-ico']").click()
time.sleep(1)
driver.find_element_by_xpath("//div[@id='detailsForm:j_idt589:0:j_idt590:header']//td[@class='rf-cp-ico']").click()


##############################
# click tree tab in tree panel
driver.find_element_by_id("contentForm:treeTab:header:inactive").click()
time.sleep(1)

time.sleep(3)
driver.quit()

# %% [markdown]
# ## Details Panel Test

# %% [markdown]
# ### Subconcept and Term selection and version loop
#
# <u>The below code does the following:</u>
# - Clicks on namespace (States of the Union, Triad, **need ontylog extension**)
# - Clicks through subconcepts, superconcepts, associations, synonyms, terms
# - Loops through versioning for the above
# - Goes back to the tree panel to click namespace and collapse tree
#
# Each type of namespace is a different block.
#
# ##### <u>Note:</u>
# When selecting namespaces, the end brackets '[]' selects the number in which they appear in the tree
# - Starts from 0, i.e., first namespace in the tree will be [0], second will be [1], and so forth
# - When running the code, **be sure to adjust these numbers at the end of the code!**

# %%
# click on subconcept and term; loop through versions
driver = webdriver.Firefox(executable_path = driver_loc, log_path = gecko_log)

def DTS_login():
    driver.get ('http://dtsadminuser:dtsadmin@localhost:8080/dtsserverws/')
       
DTS_login()

driver.maximize_window()
time.sleep(0.5)

#########################################
# STATES OF THE UNION
#########################################
# selects States of the Union
driver.find_element_by_link_text("States of the Union").click()
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")[5].click()
time.sleep(1)

driver.find_element_by_link_text("States").click()
time.sleep(1)

# click association
driver.find_element_by_link_text("Democrats").click()
time.sleep(1)

# loop through versioning of association
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from current to version
type_select.select_by_visible_text('Version')
time.sleep(2)

select = Select(driver.find_element_by_id("detailsForm:concept_version")) # loop
options = select.options
time.sleep(1)

for opt in select.options:
    opt.click()
    
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# go back to working version
version = Select(driver.find_element_by_id("detailsForm:concept_version")); # go to most recent version
version.select_by_visible_text('Working')

# select current type
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from version to current
type_select.select_by_visible_text('Current')
time.sleep(2)

# click association
driver.find_element_by_link_text("New York").click()
time.sleep(1)
# click inverse association
driver.find_element_by_link_text("East").click()
time.sleep(1)
# click inverse association
driver.find_element_by_link_text("States").click()
time.sleep(1)
# click association
driver.find_element_by_link_text("South").click()
time.sleep(1)
# click association
driver.find_element_by_link_text("Alabama").click()
time.sleep(1)
# click synonym/term
driver.find_element_by_link_text("Bama").click()
time.sleep(2)

# term version loop
# select version
type_select = Select(driver.find_element_by_id("detailsForm:j_idt220")); # change current to version
type_select.select_by_visible_text('Version')
time.sleep(2)

# loop
select = Select(driver.find_element_by_id("detailsForm:term_version")) # loop
options = select.options
time.sleep(1)

for opt in select.options:
    opt.click()
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt227").click()
time.sleep(1)
    
# go back to working version
version = Select(driver.find_element_by_id("detailsForm:term_version")); # change to most recent version
version.select_by_visible_text('Working')

# refresh
driver.find_element_by_id("detailsForm:j_idt227").click()
time.sleep(1)

# select current type
type_select = Select(driver.find_element_by_id("detailsForm:j_idt220")); # change from version to current
type_select.select_by_visible_text('Current')
time.sleep(2)

driver.find_element_by_link_text("Alabama").click()
time.sleep(1)

# go back to tree panel and collapse
driver.find_element_by_link_text("States of the Union").click()
time.sleep(1)
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-exp rf-trn-hnd']")[0].click() # collapse all

#########################################
# STATES OF THE UNION
#########################################
# Triad - INFERRED
driver.find_element_by_link_text("Triad").click()
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-colps rf-trn-hnd']")[7].click()
time.sleep(1)

# click child concept
driver.find_element_by_link_text("DIAGNOSIS").click()
time.sleep(1)

# inferred concept
type_select = Select(driver.find_element_by_id("detailsForm:j_idt213")); # change from current to version
type_select.select_by_visible_text('Inferred')
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# click subconcept
driver.find_element_by_link_text("BACK_PAIN").click()
time.sleep(1)

# loop through versioning for subconcept
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from current to version
type_select.select_by_visible_text('Version')
time.sleep(2)

select = Select(driver.find_element_by_id("detailsForm:concept_version")) # loop
options = select.options
time.sleep(1)

for opt in select.options:
    opt.click()
    
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# go back to most recent version
version = Select(driver.find_element_by_id("detailsForm:concept_version")); # go back to most recent version
version.select_by_visible_text('2010.02(Feb 1, 2010 12:00:00 AM)')

# select current type
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from version to current
type_select.select_by_visible_text('Current')
time.sleep(2)

# click synonym/term
driver.find_element_by_link_text("Back Pain").click()
time.sleep(1)

# term version loop
# select version
type_select = Select(driver.find_element_by_id("detailsForm:j_idt220")); # change from current to version
type_select.select_by_visible_text('Version')
time.sleep(2)

# loop
select = Select(driver.find_element_by_id("detailsForm:term_version")) # loop
options = select.options
time.sleep(1)

for opt in select.options:
    opt.click()
time.sleep(2)

################### THIS IS A BUG - REFRESHING MAKES TERM IN DETAILS PANEL GO BLANK
# refresh
# driver.find_element_by_id("detailsForm:j_idt227").click()
# time.sleep(1)
    
# go back to most recent version
version = Select(driver.find_element_by_id("detailsForm:term_version")); # go back to most recent version
version.select_by_visible_text('2010.02(Feb 1, 2010 12:00:00 AM)')

# select current type
type_select = Select(driver.find_element_by_id("detailsForm:j_idt220")); # change version to current
type_select.select_by_visible_text('Current')
time.sleep(2)

################## REFRESHING TERM IN DETAILS PANEL IS STILL BLANK
# refresh
# driver.find_element_by_id("detailsForm:j_idt227").click()
# time.sleep(1)

# go back to subconcept, back pain
driver.find_element_by_link_text("BACK_PAIN").click()
time.sleep(1)
# click association
driver.find_element_by_link_text("QUALITATIVE_ANALYSIS").click()
time.sleep(1)
# click superconcept
driver.find_element_by_link_text("ANALYTIC_TECHNIQUE").click()
time.sleep(1)
# click subconcept
driver.find_element_by_link_text("QUANTITATIVE_ANALYSIS").click()
time.sleep(1)
# click inverse association
driver.find_element_by_link_text("LIPID_PROFILE").click()
time.sleep(2)

# click child concept
driver.find_element_by_link_text("DIAGNOSIS").click()
time.sleep(1)

##################
# Triad - DEFINED
type_select = Select(driver.find_element_by_id("detailsForm:j_idt213")); # change from current to version
type_select.select_by_visible_text('Defined')
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# click subconcept
driver.find_element_by_link_text("BACK_PAIN").click()
time.sleep(1)


# loop through versioning for subconcept
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from current to version
type_select.select_by_visible_text('Version')
time.sleep(2)

select = Select(driver.find_element_by_id("detailsForm:concept_version")) # loop
options = select.options
time.sleep(1)

for opt in select.options:
    opt.click()
    
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

# go back to most recent version
version = Select(driver.find_element_by_id("detailsForm:concept_version")); # go back to most recent version
version.select_by_visible_text('2010.02(Feb 1, 2010 12:00:00 AM)')

# select current type
type_select = Select(driver.find_element_by_id("detailsForm:j_idt204")); # change from version to current
type_select.select_by_visible_text('Current')
time.sleep(2)

# click synonym/term
driver.find_element_by_link_text("Back Pain").click()
time.sleep(1)

# term version loop
# select version
type_select = Select(driver.find_element_by_id("detailsForm:j_idt220")); # change from current to version
type_select.select_by_visible_text('Version')
time.sleep(2)

# loop
select = Select(driver.find_element_by_id("detailsForm:term_version")) # loop
options = select.options
time.sleep(1)

for opt in select.options:
    opt.click()
time.sleep(2)

################### THIS IS A BUG - REFRESHING MAKES TERM IN DETAILS PANEL GO BLANK
# refresh
# driver.find_element_by_id("detailsForm:j_idt227").click()
# time.sleep(1)
    
# go back to most recent version
version = Select(driver.find_element_by_id("detailsForm:term_version")); # go back to most recent version
version.select_by_visible_text('2010.02(Feb 1, 2010 12:00:00 AM)')

# select current type
type_select = Select(driver.find_element_by_id("detailsForm:j_idt220")); # change version to current
type_select.select_by_visible_text('Current')
time.sleep(2)

################## REFRESHING TERM IN DETAILS PANEL IS STILL BLANK
# refresh
# driver.find_element_by_id("detailsForm:j_idt227").click()
# time.sleep(1)

# go back to subconcept, back pain
driver.find_element_by_link_text("BACK_PAIN").click()
time.sleep(1)
# click association
driver.find_element_by_link_text("QUALITATIVE_ANALYSIS").click()
time.sleep(1)
# click superconcept
driver.find_element_by_link_text("ANALYTIC_TECHNIQUE").click()
time.sleep(1)
# click subconcept
driver.find_element_by_link_text("QUANTITATIVE_ANALYSIS").click()
time.sleep(1)
# click inverse association
driver.find_element_by_link_text("LIPID_PROFILE").click()
time.sleep(2)

# click the tree panel again and collapse Triad
driver.find_element_by_link_text("DIAGNOSIS").click()
time.sleep(1)

# go back to inferred
type_select = Select(driver.find_element_by_id("detailsForm:j_idt213")); # change from current to version
type_select.select_by_visible_text('Inferred')
time.sleep(2)

# refresh
driver.find_element_by_id("detailsForm:j_idt211").click()
time.sleep(1)

driver.find_element_by_link_text("Triad").click()
time.sleep(1)
driver.find_elements_by_xpath("//div[@class='rf-trn']//span[@class='rf-trn-hnd-exp rf-trn-hnd']")[0].click() # collapse all
time.sleep(1)

time.sleep(3)
driver.quit()
